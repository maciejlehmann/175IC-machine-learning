# %% [markdown]
# <a href="https://colab.research.google.com/github/maciejlehmann/175IC-machine-learning/blob/main/Zad_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

data = {
    'size' : [np.nan, 'L', 'M', 'XL', 'M', np.nan, 'M', 'XXL', 'XL', 'L', 'M', 'XL', 'S', 'S', 'XL', 'M', 'L', np.nan, 'S', 'XL'],
    'color' : [np.nan, 'blue', np.nan, 'blue', 'green', 'black', np.nan, 'yellow', 'blue', 'black', 'green', 'blue', 'white', 'black', 'yellow', 'black', 'white', np.nan, 'blue', 'black'],
    'gender' : ['male', 'female', np.nan, 'male', np.nan, 'female', np.nan, 'female', 'male', 'female', 'male', np.nan, 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female'],
    'price' : [np.nan, 90.0, np.nan, 141.0, 120.0, 84.0, np.nan, 174.0, np.nan, 230.0, np.nan, 129.0, 141.0, 165.0, 191.0, 80.0, 150.0, np.nan, 233.0, 97.0],
    'weight' : [np.nan, 67.0, 65.0, np.nan, 73.0, 89.0, 102.0, np.nan, 78.0, 77.0, 73.0, 45.0, 101.0, 73.0, 64.0, 67.0, 100.0, np.nan, 59.0, 61.0],
    'bought': ['no', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'no', 'yes', 'no', 'yes', 'no']
}

df_raw = pd.DataFrame(data=data)
df = df_raw.copy()

# Zadanie 1
df1 = df;
df1.dropna(thresh=len(df1.keys())-2, inplace=True)
print(df1);

# Zadanie 2
df2 = df;
df2['price'].fillna(df2['price'].mean(), inplace=True)
print(df2);

# Zadanie 3
df3 = df;
df3['weight'].interpolate(inplace=True)
print(df3);

# Zadanie 4
df4 = df;
df4['gender'].fillna('male', inplace=True)
df4['size'].fillna('unisex', inplace=True)
df4['color'].fillna('black', inplace=True)
print(df4);

# Zadanie 5
df5 = df2;
df5['cost'] = pd.cut(df5['price'], bins=3, labels=["cheap", "normal", "expensive"])
print(df5)

# Zadanie 6
df6 = df;
df6['bought'].replace(to_replace="yes", value=bin(1), inplace=True)
df6['bought'].replace(to_replace="no", value=bin(0), inplace=True)
print(df6);

# Zadanie 7
df7 = df;
data = df[['size', 'color', 'gender', 'cost']]
target = df['bought']
x_train, x_test, y_train, y_test = train_test_split(data, target)
# Out:
#    size   color  gender  price  weight bought
# 1     L    blue  female   90.0    67.0    yes
# 3    XL    blue    male  141.0     NaN    yes
# 4     M   green     NaN  120.0    73.0     no
# 5   NaN   black  female   84.0    89.0    yes
# 7   XXL  yellow  female  174.0     NaN    yes
# 8    XL    blue    male    NaN    78.0     no
# 9     L   black  female  230.0    77.0    yes
# 10    M   green    male    NaN    73.0     no
# 11   XL    blue     NaN  129.0    45.0    yes
# 12    S   white    male  141.0   101.0     no
# 13    S   black  female  165.0    73.0    yes
# 14   XL  yellow    male  191.0    64.0     no
# 15    M   black  female   80.0    67.0     no
# 16    L   white    male  150.0   100.0    yes
# 18    S    blue    male  233.0    59.0    yes
# 19   XL   black  female   97.0    61.0     no
#    size   color  gender       price  weight bought
# 1     L    blue  female   90.000000    67.0    yes
# 3    XL    blue    male  141.000000     NaN    yes
# 4     M   green     NaN  120.000000    73.0     no
# 5   NaN   black  female   84.000000    89.0    yes
# 7   XXL  yellow  female  174.000000     NaN    yes
# 8    XL    blue    male  144.642857    78.0     no
# 9     L   black  female  230.000000    77.0    yes
# 10    M   green    male  144.642857    73.0     no
# 11   XL    blue     NaN  129.000000    45.0    yes
# 12    S   white    male  141.000000   101.0     no
# 13    S   black  female  165.000000    73.0    yes
# 14   XL  yellow    male  191.000000    64.0     no
# 15    M   black  female   80.000000    67.0     no
# 16    L   white    male  150.000000   100.0    yes
# 18    S    blue    male  233.000000    59.0    yes
# 19   XL   black  female   97.000000    61.0     no
#    size   color  gender       price  weight bought
# 1     L    blue  female   90.000000    67.0    yes
# 3    XL    blue    male  141.000000    70.0    yes
# 4     M   green     NaN  120.000000    73.0     no
# 5   NaN   black  female   84.000000    89.0    yes
# 7   XXL  yellow  female  174.000000    83.5    yes
# 8    XL    blue    male  144.642857    78.0     no
# 9     L   black  female  230.000000    77.0    yes
# 10    M   green    male  144.642857    73.0     no
# 11   XL    blue     NaN  129.000000    45.0    yes
# 12    S   white    male  141.000000   101.0     no
# 13    S   black  female  165.000000    73.0    yes
# 14   XL  yellow    male  191.000000    64.0     no
# 15    M   black  female   80.000000    67.0     no
# 16    L   white    male  150.000000   100.0    yes
# 18    S    blue    male  233.000000    59.0    yes
# 19   XL   black  female   97.000000    61.0     no
#       size   color  gender       price  weight bought
# 1        L    blue  female   90.000000    67.0    yes
# 3       XL    blue    male  141.000000    70.0    yes
# 4        M   green    male  120.000000    73.0     no
# 5   unisex   black  female   84.000000    89.0    yes
# 7      XXL  yellow  female  174.000000    83.5    yes
# 8       XL    blue    male  144.642857    78.0     no
# 9        L   black  female  230.000000    77.0    yes
# 10       M   green    male  144.642857    73.0     no
# 11      XL    blue    male  129.000000    45.0    yes
# 12       S   white    male  141.000000   101.0     no
# 13       S   black  female  165.000000    73.0    yes
# 14      XL  yellow    male  191.000000    64.0     no
# 15       M   black  female   80.000000    67.0     no
# 16       L   white    male  150.000000   100.0    yes
# 18       S    blue    male  233.000000    59.0    yes
# 19      XL   black  female   97.000000    61.0     no
#       size   color  gender       price  weight bought       cost
# 1        L    blue  female   90.000000    67.0    yes      cheap
# 3       XL    blue    male  141.000000    70.0    yes     normal
# 4        M   green    male  120.000000    73.0     no      cheap
# 5   unisex   black  female   84.000000    89.0    yes      cheap
# 7      XXL  yellow  female  174.000000    83.5    yes     normal
# 8       XL    blue    male  144.642857    78.0     no     normal
# 9        L   black  female  230.000000    77.0    yes  expensive
# 10       M   green    male  144.642857    73.0     no     normal
# 11      XL    blue    male  129.000000    45.0    yes      cheap
# 12       S   white    male  141.000000   101.0     no     normal
# 13       S   black  female  165.000000    73.0    yes     normal
# 14      XL  yellow    male  191.000000    64.0     no  expensive
# 15       M   black  female   80.000000    67.0     no      cheap
# 16       L   white    male  150.000000   100.0    yes     normal
# 18       S    blue    male  233.000000    59.0    yes  expensive
# 19      XL   black  female   97.000000    61.0     no      cheap
#       size   color  gender       price  weight bought       cost
# 1        L    blue  female   90.000000    67.0    0b1      cheap
# 3       XL    blue    male  141.000000    70.0    0b1     normal
# 4        M   green    male  120.000000    73.0    0b0      cheap
# 5   unisex   black  female   84.000000    89.0    0b1      cheap
# 7      XXL  yellow  female  174.000000    83.5    0b1     normal
# 8       XL    blue    male  144.642857    78.0    0b0     normal
# 9        L   black  female  230.000000    77.0    0b1  expensive
# 10       M   green    male  144.642857    73.0    0b0     normal
# 11      XL    blue    male  129.000000    45.0    0b1      cheap
# 12       S   white    male  141.000000   101.0    0b0     normal
# 13       S   black  female  165.000000    73.0    0b1     normal
# 14      XL  yellow    male  191.000000    64.0    0b0  expensive
# 15       M   black  female   80.000000    67.0    0b0      cheap
# 16       L   white    male  150.000000   100.0    0b1     normal
# 18       S    blue    male  233.000000    59.0    0b1  expensive
# 19      XL   black  female   97.000000    61.0    0b0      cheap
