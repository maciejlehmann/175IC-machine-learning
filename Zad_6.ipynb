# %% [markdown]
# <a href="https://colab.research.google.com/github/maciejlehmann/175IC-machine-learning/blob/main/Zad_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np

# Zadanie 1

iris = datasets.load_iris()
X = iris.data[:, :2]
y = iris.target

# Zadanie 2

x_train,x_test,y_train,y_test=train_test_split(X, y, test_size=0.4)

# %%
# Zadanie 3

clf = SVC(C=1.5, kernel='linear')
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
plot_decision_regions(x_train, y_train, clf=clf)

plt.title(f'Dokładność klasyfikacji = {round(accuracy, 2)}')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
# Zadanie 4 - C = 0.7, kernel = linear

clf = SVC(C=0.7, kernel='linear')
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
plot_decision_regions(x_train, y_train, clf=clf)

plt.title(f'Dokładność klasyfikacji = {round(accuracy, 2)}')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
# Zadanie 4 - C = 0.333, kernel = poly

clf = SVC(C=0.333, kernel='poly')
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
plot_decision_regions(x_train, y_train, clf=clf)

plt.title(f'Dokładność klasyfikacji = {round(accuracy, 2)}')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
# Zadanie 4 - C = 1, kernel = rbf

clf = SVC(C=1, kernel='rbf')
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
plot_decision_regions(x_train, y_train, clf=clf)

plt.title(f'Dokładność klasyfikacji = {round(accuracy, 2)}')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
# Zadanie 4 - C = 0.05, kernel = sigmoid

clf = SVC(C=0.05, kernel='sigmoid')
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
plot_decision_regions(x_train, y_train, clf=clf)

plt.title(f'Dokładność klasyfikacji = {round(accuracy, 2)}')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:242: UserWarning: No contour levels were found within the data range.
#   antialiased=True)
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
